# %%
data = 5

while data >= 0:
    print("data ==", data)
    data -= 1
# Out:
# data == 5
# data == 4
# data == 3
# data == 2
# data == 1
# data == 0

# %%
data = 5

while data >= 0:
    print("data ==", data)
    data -= 1
    
    if data == 2:
        print("break here")
        break
    else:
        print("continue here") 
        continue
# Out:
# data == 5
# continue here
# data == 4
# continue here
# data == 3
# break here
