# %% [markdown]
# ### ML_LEC_42_Colab_Example 는 일반 PC가 아닌
# ### Google Colab (https://colab.research.google.com/) 에서 실행한 예제임

# %% [markdown]
# #### 일반 PC에서 Colab 으로 파일 업로드 예제

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-8147a2f1-c9f9-4676-a682-81dffacc8177" name="files[]" multiple disabled />
#      <output id="result-8147a2f1-c9f9-4676-a682-81dffacc8177">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sigmoid.py to sigmoid.py
# User uploaded file "sigmoid.py" with length 191 bytes

# %% [markdown]
# #### Colab 에서 일반 PC로 파일 다운로드 예제

# %%
import pandas as pd

# %%
df = pd.DataFrame([ [1,2,3], [10,20,30] ])

df
# Out:
#     0   1   2
# 0   1   2   3
# 1  10  20  30

# %%
df.to_csv('test.csv')

# %%
# !ls -l
# Out:
# total 12
# drwxr-xr-x 1 root root 4096 Aug  2 16:06 sample_data
# -rw-r--r-- 1 root root  191 Aug 16 04:08 sigmoid.py
# -rw-r--r-- 1 root root   26 Aug 16 04:10 test.csv

# %%
files.download('test.csv')
