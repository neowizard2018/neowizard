# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# 입력노드, 은닉노드, 출력노드, 학습율, 반복횟수, 배치 개수 등 설정
learning_rate = 0.1  # 학습율
epochs = 100            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

input_nodes = 784     # 입력노드 개수
hidden_nodes = 100    # 은닉노드 개수
output_nodes = 10     # 출력노드 개수

# %%
# 입력과 출력을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, input_nodes])  
T = tf.placeholder(tf.float32, [None, output_nodes])  

W2 = tf.Variable(tf.random_normal([input_nodes, hidden_nodes]))  # 은닉층 가중치 노드
b2 = tf.Variable(tf.random_normal([hidden_nodes]))               # 은닉층 바이어스 노드

W3 = tf.Variable(tf.random_normal([hidden_nodes, output_nodes])) # 출력층 가중치 노드
b3 = tf.Variable(tf.random_normal([output_nodes]))               # 출력층 바이어스 노드

# %%
Z2 = tf.matmul(X, W2) + b2    # 선형회귀 선형회귀 값 Z2
A2 = tf.nn.relu(Z2)           # 은닉층 출력 값 A2, sigmoid 대신 relu 사용

# 출력층 선형회귀  값 Z3, 즉 softmax 에 들어가는 입력 값
Z3 = logits = tf.matmul(A2, W3) + b3   

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z3, labels=T) )

optimizer = tf.train.GradientDescentOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A3, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# %%
with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    for i in range(epochs):    # 100 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("step = ", step, ", loss_val = ", loss_val)             
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val = sess.run(accuracy, feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
# Out:
# step =  0 , loss_val =  98.7612
# step =  100 , loss_val =  4.2225432
# step =  200 , loss_val =  3.0104418
# step =  300 , loss_val =  4.0216117
# step =  400 , loss_val =  1.4966797
# step =  500 , loss_val =  3.3441987
# step =  0 , loss_val =  2.2555325
# step =  100 , loss_val =  0.7794918
# step =  200 , loss_val =  0.780978
# step =  300 , loss_val =  0.79618454
# step =  400 , loss_val =  1.4270331
# step =  500 , loss_val =  1.1760174
# step =  0 , loss_val =  0.8210196
# step =  100 , loss_val =  0.78998846
# step =  200 , loss_val =  1.0108494
# step =  300 , loss_val =  0.5986542
# step =  400 , loss_val =  0.69406706
# step =  500 , loss_val =  0.596174
# step =  0 , loss_val =  0.5947503
# step =  100 , loss_val =  0.5289751
# step =  200 , loss_val =  0.89512247
# step =  300 , loss_val =  0.087289646
# step =  400 , loss_val =  1.047837
# step =  500 , loss_val =  0.67628634
# step =  0 , loss_val =  0.5862404
# step =  100 , loss_val =  0.356495
# step =  200 , loss_val =  0.5103785
# step =  300 , loss_val =  0.21166834
# step =  400 , loss_val =  0.65034574
# step =  500 , loss_val =  0.4542511
# step =  0 , loss_val =  0.32343915
# step =  100 , loss_val =  0.14856976
# step =  200 , loss_val =  0.40807945
# step =  300 , loss_val =  0.34825328
# step =  400 , loss_val =  0.44345036
# step =  500 , loss_val =  0.8494026
# step =  0 , loss_val =  0.21821935
# step =  100 , loss_val =  0.12743305
# step =  200 , loss_val =  0.381132
# step =  300 , loss_val =  0.34117648
# step =  400 , loss_val =  0.419109
# step =  500 , loss_val =  0.26673216
# step =  0 , loss_val =  0.61018914
# step =  100 , loss_val =  0.5838667
# step =  200 , loss_val =  0.2757722
# step =  300 , loss_val =  0.31328785
# step =  400 , loss_val =  0.35858372
# step =  500 , loss_val =  0.6389467
# step =  0 , loss_val =  0.27090618
# step =  100 , loss_val =  0.33916524
# step =  200 , loss_val =  0.5682698
# step =  300 , loss_val =  0.52870864
# step =  400 , loss_val =  0.37700817
# step =  500 , loss_val =  0.24603006
# step =  0 , loss_val =  0.35203987
# step =  100 , loss_val =  0.18561672
# step =  200 , loss_val =  0.21185215
# step =  300 , loss_val =  0.3643334
# step =  400 , loss_val =  0.47864944
# step =  500 , loss_val =  0.34858936
# step =  0 , loss_val =  0.18307026
# step =  100 , loss_val =  0.16692841
# step =  200 , loss_val =  0.2539686
# step =  300 , loss_val =  0.56319153
# step =  400 , loss_val =  0.3757007
# step =  500 , loss_val =  0.1605877
# step =  0 , loss_val =  0.45068976
# step =  100 , loss_val =  0.36821434
# step =  200 , loss_val =  0.22739208
# step =  300 , loss_val =  0.29825202
# step =  400 , loss_val =  0.48310632
# step =  500 , loss_val =  0.20147343
# step =  0 , loss_val =  0.29958126
# step =  100 , loss_val =  0.21494482
# step =  200 , loss_val =  0.26633647
# step =  300 , loss_val =  0.1382255
# step =  400 , loss_val =  0.24266842
# step =  500 , loss_val =  0.26199308
# step =  0 , loss_val =  0.13014765
# step =  100 , loss_val =  0.2926132
# step =  200 , loss_val =  0.3359369
# step =  300 , loss_val =  0.3724978
# step =  400 , loss_val =  0.29507026
# step =  500 , loss_val =  0.4948552
# step =  0 , loss_val =  0.21024232
# step =  100 , loss_val =  0.23355389
# step =  200 , loss_val =  0.36412293
# step =  300 , loss_val =  0.306574
# step =  400 , loss_val =  0.3469176
# step =  500 , loss_val =  0.7050893
# step =  0 , loss_val =  0.10489171
# step =  100 , loss_val =  0.37852713
# step =  200 , loss_val =  0.28591812
# step =  300 , loss_val =  0.27504376
# step =  400 , loss_val =  0.278767
# step =  500 , loss_val =  0.23139656
# step =  0 , loss_val =  0.22364019
# step =  100 , loss_val =  0.18635595
# step =  200 , loss_val =  0.13331558
# step =  300 , loss_val =  0.1347872
# step =  400 , loss_val =  0.21931995
# step =  500 , loss_val =  0.361093
# step =  0 , loss_val =  0.4195029
# step =  100 , loss_val =  0.30116755
# step =  200 , loss_val =  0.1947394
# step =  300 , loss_val =  0.30907178
# step =  400 , loss_val =  0.17729938
# step =  500 , loss_val =  0.08906861
# step =  0 , loss_val =  0.11876607
# step =  100 , loss_val =  0.051215254
# step =  200 , loss_val =  0.1834663
# step =  300 , loss_val =  0.14015083
# step =  400 , loss_val =  0.15379559
# step =  500 , loss_val =  0.37076396
# step =  0 , loss_val =  0.4387962
# step =  100 , loss_val =  0.12057539
# step =  200 , loss_val =  0.17525944
# step =  300 , loss_val =  0.28515592
# step =  400 , loss_val =  0.21672867
# step =  500 , loss_val =  0.3430142
# step =  0 , loss_val =  0.16086802
# step =  100 , loss_val =  0.14855103
# step =  200 , loss_val =  0.2603812
# step =  300 , loss_val =  0.23901352
# step =  400 , loss_val =  0.2391769
# step =  500 , loss_val =  0.15039206
# step =  0 , loss_val =  0.09541407
# step =  100 , loss_val =  0.16803348
# step =  200 , loss_val =  0.09772897
# step =  300 , loss_val =  0.35757375
# step =  400 , loss_val =  0.1014431
# step =  500 , loss_val =  0.07668622
# step =  0 , loss_val =  0.1830911
# step =  100 , loss_val =  0.15749641
# step =  200 , loss_val =  0.16757166
# step =  300 , loss_val =  0.1463781
# step =  400 , loss_val =  0.33151984
# step =  500 , loss_val =  0.13304113
# step =  0 , loss_val =  0.13166688
# step =  100 , loss_val =  0.3050455
# step =  200 , loss_val =  0.2013363
# step =  300 , loss_val =  0.19239445
# step =  400 , loss_val =  0.17040646
# step =  500 , loss_val =  0.4005661
# step =  0 , loss_val =  0.15859005
# step =  100 , loss_val =  0.20646714
# step =  200 , loss_val =  0.124406874
# step =  300 , loss_val =  0.04993471
# step =  400 , loss_val =  0.28474545
# step =  500 , loss_val =  0.08969848
# step =  0 , loss_val =  0.20537663
# step =  100 , loss_val =  0.11635953
# step =  200 , loss_val =  0.12121176
# step =  300 , loss_val =  0.353941
# step =  400 , loss_val =  0.12721626
# step =  500 , loss_val =  0.22403862
# step =  0 , loss_val =  0.19975016
# step =  100 , loss_val =  0.22187233
# step =  200 , loss_val =  0.21112174
# step =  300 , loss_val =  0.39483425
# step =  400 , loss_val =  0.20455247
# step =  500 , loss_val =  0.21208915
# step =  0 , loss_val =  0.16818999
# step =  100 , loss_val =  0.18583387
# step =  200 , loss_val =  0.09398469
# step =  300 , loss_val =  0.10961437
# step =  400 , loss_val =  0.14373398
# step =  500 , loss_val =  0.075184844
# step =  0 , loss_val =  0.2371954
# step =  100 , loss_val =  0.13246933
# step =  200 , loss_val =  0.09185058
# step =  300 , loss_val =  0.37816197
# step =  400 , loss_val =  0.31048682
# step =  500 , loss_val =  0.14360327
# step =  0 , loss_val =  0.19106591
# step =  100 , loss_val =  0.09956969
# step =  200 , loss_val =  0.3261602
# step =  300 , loss_val =  0.14425273
# step =  400 , loss_val =  0.21968104
# step =  500 , loss_val =  0.108507775
# step =  0 , loss_val =  0.05156836
# step =  100 , loss_val =  0.18976122
# step =  200 , loss_val =  0.19961385
# step =  300 , loss_val =  0.20520449
# step =  400 , loss_val =  0.109947294
# step =  500 , loss_val =  0.2708654
# step =  0 , loss_val =  0.1493591
# step =  100 , loss_val =  0.21095861
# step =  200 , loss_val =  0.21549067
# step =  300 , loss_val =  0.23511125
# step =  400 , loss_val =  0.22926454
# step =  500 , loss_val =  0.29214773
# step =  0 , loss_val =  0.17390706
# step =  100 , loss_val =  0.3742662
# step =  200 , loss_val =  0.16589323
# step =  300 , loss_val =  0.06805904
# step =  400 , loss_val =  0.23802835
# step =  500 , loss_val =  0.15283716
# step =  0 , loss_val =  0.088908106
# step =  100 , loss_val =  0.284499
# step =  200 , loss_val =  0.11114723
# step =  300 , loss_val =  0.15632583
# step =  400 , loss_val =  0.077977754
# step =  500 , loss_val =  0.08073903
# step =  0 , loss_val =  0.19254738
# step =  100 , loss_val =  0.21455307
# step =  200 , loss_val =  0.12194917
# step =  300 , loss_val =  0.100222915
# step =  400 , loss_val =  0.13815197
# step =  500 , loss_val =  0.19414712
# step =  0 , loss_val =  0.16082129
# step =  100 , loss_val =  0.21534309
# step =  200 , loss_val =  0.15439756
# step =  300 , loss_val =  0.2328979
# step =  400 , loss_val =  0.042886563
# step =  500 , loss_val =  0.09681396
# step =  0 , loss_val =  0.13092673
# step =  100 , loss_val =  0.45962146
# step =  200 , loss_val =  0.06721954
# step =  300 , loss_val =  0.12235124
# step =  400 , loss_val =  0.099766925
# step =  500 , loss_val =  0.050248165
# step =  0 , loss_val =  0.22014494
# step =  100 , loss_val =  0.08573104
# step =  200 , loss_val =  0.22813886
# step =  300 , loss_val =  0.09476366
# step =  400 , loss_val =  0.1513649
# step =  500 , loss_val =  0.049496032
# step =  0 , loss_val =  0.08142288
# step =  100 , loss_val =  0.07289451
# step =  200 , loss_val =  0.1780903
# step =  300 , loss_val =  0.10608853
# step =  400 , loss_val =  0.37784445
# step =  500 , loss_val =  0.12832195
# step =  0 , loss_val =  0.14666119
# step =  100 , loss_val =  0.14054361
# step =  200 , loss_val =  0.17657375
# step =  300 , loss_val =  0.20458196
# step =  400 , loss_val =  0.11803718
# step =  500 , loss_val =  0.13847123
# step =  0 , loss_val =  0.25573272
# step =  100 , loss_val =  0.18201187
# step =  200 , loss_val =  0.091284245
# step =  300 , loss_val =  0.17250858
# step =  400 , loss_val =  0.19891079
# step =  500 , loss_val =  0.21771426
# step =  0 , loss_val =  0.178704
# step =  100 , loss_val =  0.13463748
# step =  200 , loss_val =  0.2924022
# step =  300 , loss_val =  0.11109094
# step =  400 , loss_val =  0.20054968
# step =  500 , loss_val =  0.20920691
# step =  0 , loss_val =  0.2338718
# step =  100 , loss_val =  0.04285978
# step =  200 , loss_val =  0.16211925
# step =  300 , loss_val =  0.29610917
# step =  400 , loss_val =  0.1601205
# step =  500 , loss_val =  0.10381627
# step =  0 , loss_val =  0.14728828
# step =  100 , loss_val =  0.3165634
# step =  200 , loss_val =  0.092284516
# step =  300 , loss_val =  0.14332739
# step =  400 , loss_val =  0.16970426
# step =  500 , loss_val =  0.113992766
# step =  0 , loss_val =  0.18203156
# step =  100 , loss_val =  0.09198416
# step =  200 , loss_val =  0.060730588
# step =  300 , loss_val =  0.15817423
# step =  400 , loss_val =  0.21142101
# step =  500 , loss_val =  0.2621069
# step =  0 , loss_val =  0.26956233
# step =  100 , loss_val =  0.12209714
# step =  200 , loss_val =  0.106616065
# step =  300 , loss_val =  0.22773805
# step =  400 , loss_val =  0.12230304
# step =  500 , loss_val =  0.19549978
# step =  0 , loss_val =  0.20330632
# step =  100 , loss_val =  0.10932177
# step =  200 , loss_val =  0.1755512
# step =  300 , loss_val =  0.16661379
# step =  400 , loss_val =  0.1131948
# step =  500 , loss_val =  0.17006801
# step =  0 , loss_val =  0.101953775
# step =  100 , loss_val =  0.053898763
# step =  200 , loss_val =  0.32179517
# step =  300 , loss_val =  0.15734063
# step =  400 , loss_val =  0.20284739
# step =  500 , loss_val =  0.1141882
# step =  0 , loss_val =  0.15662974
# step =  100 , loss_val =  0.054605182
# step =  200 , loss_val =  0.18307374
# step =  300 , loss_val =  0.100900106
# step =  400 , loss_val =  0.051113654
# step =  500 , loss_val =  0.16306373
# step =  0 , loss_val =  0.20563802
# step =  100 , loss_val =  0.109280735
# step =  200 , loss_val =  0.036251232
# step =  300 , loss_val =  0.22617197
# step =  400 , loss_val =  0.11493063
# step =  500 , loss_val =  0.06290147
# step =  0 , loss_val =  0.25853202
# step =  100 , loss_val =  0.116271496
# step =  200 , loss_val =  0.04531177
# step =  300 , loss_val =  0.116152495
# step =  400 , loss_val =  0.17723471
# step =  500 , loss_val =  0.12434194
# step =  0 , loss_val =  0.06896304
# step =  100 , loss_val =  0.22119701
# step =  200 , loss_val =  0.109577835
# step =  300 , loss_val =  0.22097756
# step =  400 , loss_val =  0.03198345
# step =  500 , loss_val =  0.25314364
# step =  0 , loss_val =  0.06131983
# step =  100 , loss_val =  0.24016266
# step =  200 , loss_val =  0.16429037
# step =  300 , loss_val =  0.12629895
# step =  400 , loss_val =  0.21822777
# step =  500 , loss_val =  0.13755924
# step =  0 , loss_val =  0.10092394
# step =  100 , loss_val =  0.07226853
# step =  200 , loss_val =  0.14946364
# step =  300 , loss_val =  0.2219048
# step =  400 , loss_val =  0.15261842
# step =  500 , loss_val =  0.044375505
# step =  0 , loss_val =  0.15053444
# step =  100 , loss_val =  0.17970453
# step =  200 , loss_val =  0.0134676425
# step =  300 , loss_val =  0.13404736
# step =  400 , loss_val =  0.2226424
# step =  500 , loss_val =  0.14306448
# step =  0 , loss_val =  0.15382622
# step =  100 , loss_val =  0.06600042
# step =  200 , loss_val =  0.08191186
# step =  300 , loss_val =  0.14411168
# step =  400 , loss_val =  0.044891916
# step =  500 , loss_val =  0.1331726
# step =  0 , loss_val =  0.20858757
# step =  100 , loss_val =  0.30085376
# step =  200 , loss_val =  0.08054063
# step =  300 , loss_val =  0.11506091
# step =  400 , loss_val =  0.15156025
# step =  500 , loss_val =  0.09260223
# step =  0 , loss_val =  0.11783791
# step =  100 , loss_val =  0.03146205
# step =  200 , loss_val =  0.045553125
# step =  300 , loss_val =  0.06896692
# step =  400 , loss_val =  0.09008083
# step =  500 , loss_val =  0.098399706
# step =  0 , loss_val =  0.06809532
# step =  100 , loss_val =  0.12119974
# step =  200 , loss_val =  0.17299157
# step =  300 , loss_val =  0.07866022
# step =  400 , loss_val =  0.09884501
# step =  500 , loss_val =  0.07333529
# step =  0 , loss_val =  0.1121254
# step =  100 , loss_val =  0.11113452
# step =  200 , loss_val =  0.11588703
# step =  300 , loss_val =  0.16135329
# step =  400 , loss_val =  0.085639715
# step =  500 , loss_val =  0.17147084
# step =  0 , loss_val =  0.061674334
# step =  100 , loss_val =  0.09187696
# step =  200 , loss_val =  0.10638195
# step =  300 , loss_val =  0.07115816
# step =  400 , loss_val =  0.09158175
# step =  500 , loss_val =  0.10168598
# step =  0 , loss_val =  0.13340469
# step =  100 , loss_val =  0.069113895
# step =  200 , loss_val =  0.14224885
# step =  300 , loss_val =  0.21804586
# step =  400 , loss_val =  0.07394379
# step =  500 , loss_val =  0.024699247
# step =  0 , loss_val =  0.103690974
# step =  100 , loss_val =  0.029710244
# step =  200 , loss_val =  0.14105122
# step =  300 , loss_val =  0.09814801
# step =  400 , loss_val =  0.08540955
# step =  500 , loss_val =  0.17130363
# step =  0 , loss_val =  0.14424452
# step =  100 , loss_val =  0.10738492
# step =  200 , loss_val =  0.18794979
# step =  300 , loss_val =  0.2538072
# step =  400 , loss_val =  0.06202425
# step =  500 , loss_val =  0.23082711
# step =  0 , loss_val =  0.16096373
# step =  100 , loss_val =  0.0881222
# step =  200 , loss_val =  0.0952142
# step =  300 , loss_val =  0.2357173
# step =  400 , loss_val =  0.09691262
# step =  500 , loss_val =  0.06355607
# step =  0 , loss_val =  0.12044056
# step =  100 , loss_val =  0.05790305
# step =  200 , loss_val =  0.18037853
# step =  300 , loss_val =  0.24374504
# step =  400 , loss_val =  0.16513447
# step =  500 , loss_val =  0.08435433
# step =  0 , loss_val =  0.11690323
# step =  100 , loss_val =  0.08134011
# step =  200 , loss_val =  0.07225598
# step =  300 , loss_val =  0.09656236
# step =  400 , loss_val =  0.118251026
# step =  500 , loss_val =  0.15339872
# step =  0 , loss_val =  0.24559012
# step =  100 , loss_val =  0.186541
# step =  200 , loss_val =  0.11417444
# step =  300 , loss_val =  0.07248957
# step =  400 , loss_val =  0.050550595
# step =  500 , loss_val =  0.100545414
# step =  0 , loss_val =  0.20323227
# step =  100 , loss_val =  0.08738268
# step =  200 , loss_val =  0.07834989
# step =  300 , loss_val =  0.13158709
# step =  400 , loss_val =  0.10399495
# step =  500 , loss_val =  0.09529619
# step =  0 , loss_val =  0.06968573
# step =  100 , loss_val =  0.11514949
# step =  200 , loss_val =  0.103133656
# step =  300 , loss_val =  0.12297782
# step =  400 , loss_val =  0.05583899
# step =  500 , loss_val =  0.07401517
# step =  0 , loss_val =  0.08654328
# step =  100 , loss_val =  0.02727449
# step =  200 , loss_val =  0.12110131
# step =  300 , loss_val =  0.094670475
# step =  400 , loss_val =  0.118817575
# step =  500 , loss_val =  0.017245257
# step =  0 , loss_val =  0.04584926
# step =  100 , loss_val =  0.043908186
# step =  200 , loss_val =  0.05945776
# step =  300 , loss_val =  0.08746045
# step =  400 , loss_val =  0.11767513
# step =  500 , loss_val =  0.10284833
# step =  0 , loss_val =  0.13281196
# step =  100 , loss_val =  0.03921926
# step =  200 , loss_val =  0.23921403
# step =  300 , loss_val =  0.1146641
# step =  400 , loss_val =  0.07783232
# step =  500 , loss_val =  0.18490002
# step =  0 , loss_val =  0.08579733
# step =  100 , loss_val =  0.043392286
# step =  200 , loss_val =  0.21504016
# step =  300 , loss_val =  0.12941743
# step =  400 , loss_val =  0.12821206
# step =  500 , loss_val =  0.032969777
# step =  0 , loss_val =  0.11150402
# step =  100 , loss_val =  0.09319486
# step =  200 , loss_val =  0.06297363
# step =  300 , loss_val =  0.17388223
# step =  400 , loss_val =  0.29583478
# step =  500 , loss_val =  0.17524199
# step =  0 , loss_val =  0.058684845
# step =  100 , loss_val =  0.09577307
# step =  200 , loss_val =  0.10499828
# step =  300 , loss_val =  0.079495095
# step =  400 , loss_val =  0.18582366
# step =  500 , loss_val =  0.052590493
# step =  0 , loss_val =  0.2153236
# step =  100 , loss_val =  0.026111908
# step =  200 , loss_val =  0.2527601
# step =  300 , loss_val =  0.033737943
# step =  400 , loss_val =  0.17702438
# step =  500 , loss_val =  0.14436775
# step =  0 , loss_val =  0.06970258
# step =  100 , loss_val =  0.05203901
# step =  200 , loss_val =  0.087949775
# step =  300 , loss_val =  0.11476736
# step =  400 , loss_val =  0.20422393
# step =  500 , loss_val =  0.06954722
# step =  0 , loss_val =  0.14229763
# step =  100 , loss_val =  0.082096405
# step =  200 , loss_val =  0.056677695
# step =  300 , loss_val =  0.06809659
# step =  400 , loss_val =  0.1450156
# step =  500 , loss_val =  0.095227845
# step =  0 , loss_val =  0.07464449
# step =  100 , loss_val =  0.06805339
# step =  200 , loss_val =  0.07183906
# step =  300 , loss_val =  0.041869406
# step =  400 , loss_val =  0.1131368
# step =  500 , loss_val =  0.1059004
# step =  0 , loss_val =  0.047835197
# step =  100 , loss_val =  0.19086312
# step =  200 , loss_val =  0.07131177
# step =  300 , loss_val =  0.08172615
# step =  400 , loss_val =  0.069323495
# step =  500 , loss_val =  0.16327554
# step =  0 , loss_val =  0.021323724
# step =  100 , loss_val =  0.21994747
# step =  200 , loss_val =  0.08829598
# step =  300 , loss_val =  0.041506957
# step =  400 , loss_val =  0.07668007
# step =  500 , loss_val =  0.12881464
# step =  0 , loss_val =  0.061083503
# step =  100 , loss_val =  0.12683986
# step =  200 , loss_val =  0.09348991
# step =  300 , loss_val =  0.12012135
# step =  400 , loss_val =  0.1300386
# step =  500 , loss_val =  0.08323609
# step =  0 , loss_val =  0.04238149
# step =  100 , loss_val =  0.15474741
# step =  200 , loss_val =  0.100533895
# step =  300 , loss_val =  0.07485135
# step =  400 , loss_val =  0.056983765
# step =  500 , loss_val =  0.040027622
# step =  0 , loss_val =  0.07363367
# step =  100 , loss_val =  0.119379684
# step =  200 , loss_val =  0.03393468
# step =  300 , loss_val =  0.068797514
# step =  400 , loss_val =  0.086048
# step =  500 , loss_val =  0.09428507
# step =  0 , loss_val =  0.119828895
# step =  100 , loss_val =  0.08764133
# step =  200 , loss_val =  0.10690073
# step =  300 , loss_val =  0.11141369
# step =  400 , loss_val =  0.061961398
# step =  500 , loss_val =  0.3161085
# step =  0 , loss_val =  0.036573786
# step =  100 , loss_val =  0.043955125
# step =  200 , loss_val =  0.12525643
# step =  300 , loss_val =  0.1920671
# step =  400 , loss_val =  0.05853163
# step =  500 , loss_val =  0.1489532
# step =  0 , loss_val =  0.11095838
# step =  100 , loss_val =  0.07836281
# step =  200 , loss_val =  0.23182216
# step =  300 , loss_val =  0.0960894
# step =  400 , loss_val =  0.058265056
# step =  500 , loss_val =  0.12714331
# step =  0 , loss_val =  0.095952146
# step =  100 , loss_val =  0.13418375
# step =  200 , loss_val =  0.04262578
# step =  300 , loss_val =  0.04548671
# step =  400 , loss_val =  0.10679732
# step =  500 , loss_val =  0.17114727
# step =  0 , loss_val =  0.0921601
# step =  100 , loss_val =  0.08785316
# step =  200 , loss_val =  0.036083985
# step =  300 , loss_val =  0.1274463
# step =  400 , loss_val =  0.23912555
# step =  500 , loss_val =  0.067417525
# step =  0 , loss_val =  0.059308767
# step =  100 , loss_val =  0.023116795
# step =  200 , loss_val =  0.058251154
# step =  300 , loss_val =  0.06314057
# step =  400 , loss_val =  0.14010288
# step =  500 , loss_val =  0.048797954
# step =  0 , loss_val =  0.20148699
# step =  100 , loss_val =  0.06563799
# step =  200 , loss_val =  0.07934828
# step =  300 , loss_val =  0.047502145
# step =  400 , loss_val =  0.16383389
# step =  500 , loss_val =  0.023998339
# step =  0 , loss_val =  0.08201137
# step =  100 , loss_val =  0.07072026
# step =  200 , loss_val =  0.10702058
# step =  300 , loss_val =  0.05277188
# step =  400 , loss_val =  0.048184834
# step =  500 , loss_val =  0.030623667
# step =  0 , loss_val =  0.10075039
# step =  100 , loss_val =  0.033964563
# step =  200 , loss_val =  0.12690929
# step =  300 , loss_val =  0.113888375
# step =  400 , loss_val =  0.08903967
# step =  500 , loss_val =  0.048632007
# step =  0 , loss_val =  0.12231021
# step =  100 , loss_val =  0.18957259
# step =  200 , loss_val =  0.081479184
# step =  300 , loss_val =  0.13405977
# step =  400 , loss_val =  0.036299806
# step =  500 , loss_val =  0.124054946
# step =  0 , loss_val =  0.097919285
# step =  100 , loss_val =  0.060212635
# step =  200 , loss_val =  0.02497113
# step =  300 , loss_val =  0.059030607
# step =  400 , loss_val =  0.14933683
# step =  500 , loss_val =  0.036893733
# step =  0 , loss_val =  0.07905362
# step =  100 , loss_val =  0.08835897
# step =  200 , loss_val =  0.06882985
# step =  300 , loss_val =  0.04187293
# step =  400 , loss_val =  0.10642853
# step =  500 , loss_val =  0.073265046
# step =  0 , loss_val =  0.04185644
# step =  100 , loss_val =  0.05762832
# step =  200 , loss_val =  0.13441062
# step =  300 , loss_val =  0.017584769
# step =  400 , loss_val =  0.05412395
# step =  500 , loss_val =  0.06643064
# step =  0 , loss_val =  0.06947983
# step =  100 , loss_val =  0.070318006
# step =  200 , loss_val =  0.075074956
# step =  300 , loss_val =  0.05915344
# step =  400 , loss_val =  0.030140892
# step =  500 , loss_val =  0.022581069
# step =  0 , loss_val =  0.14176598
# step =  100 , loss_val =  0.05623051
# step =  200 , loss_val =  0.025527965
# step =  300 , loss_val =  0.10016465
# step =  400 , loss_val =  0.079585046
# step =  500 , loss_val =  0.08565387
#
# Accuracy =  0.9554
