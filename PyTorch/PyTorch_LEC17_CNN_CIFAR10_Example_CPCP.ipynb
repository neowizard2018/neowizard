# %%
import torch
from torch import nn
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

print(f"using PyTorch version: {torch.__version__}, Device: {DEVICE}")
# Out:
# using PyTorch version: 2.1.0+cu121, Device: cuda

# %%
train_dataset = datasets.CIFAR10(root='CIFAR10_data/', train=True, download=True,
                               transform=transforms.ToTensor())

test_dataset = datasets.CIFAR10(root='CIFAR10_data/', train=False, download=True,
                              transform=transforms.ToTensor())
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(len(train_dataset))

train_dataset_size = int(len(train_dataset) * 0.85)
validation_dataset_size = int(len(train_dataset) * 0.15)

train_dataset, validation_dataset = random_split(train_dataset, [train_dataset_size, validation_dataset_size])

print(len(train_dataset), len(validation_dataset), len(test_dataset))
# Out:
# 50000
# 42500 7500 10000

# %%
BATCH_SIZE = 64

train_dataset_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset_loader = DataLoader(dataset=validation_dataset, batch_size=BATCH_SIZE, shuffle=True)

test_dataset_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
class MyCNNModel(nn.Module):

    def __init__(self):

        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)

        self.pooling = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(8 * 8 * 64, 128)
        self.fc2 = nn.Linear(128, 10)

        self.dropout25 = nn.Dropout(p=0.25)
        self.dropout50 = nn.Dropout(p=0.5)

    def forward(self, data):

        data = self.conv1(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv2(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = data.view(-1, 8 * 8 * 64)

        data = self.fc1(data)
        data = torch.relu(data)
        data = self.dropout50(data)

        logits = self.fc2(data)

        return logits

# %%
model = MyCNNModel().to(DEVICE)

loss_function = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)

# %%
def model_train(dataloader, model, loss_function, optimizer):

    model.train()

    train_loss_sum = train_correct = train_total = 0

    total_train_batch = len(dataloader)

    for images, labels in dataloader:

        x_train = images.to(DEVICE)
        y_train = labels.to(DEVICE)

        outputs = model(x_train)
        loss = loss_function(outputs, y_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss_sum += loss.item()

        train_total += y_train.size(0)
        train_correct += ((torch.argmax(outputs, 1)==y_train)).sum().item()

    train_avg_loss = train_loss_sum / total_train_batch
    train_avg_accuracy = 100*train_correct / train_total

    return (train_avg_loss, train_avg_accuracy)

# %%
def model_evaluate(dataloader, model, loss_function, optimizer):

    model.eval()

    with torch.no_grad():

        val_loss_sum = val_correct = val_total = 0

        total_val_batch = len(dataloader)

        for images, labels in dataloader:

            x_val = images.to(DEVICE)
            y_val = labels.to(DEVICE)

            outputs = model(x_val)
            loss = loss_function(outputs, y_val)

            val_loss_sum += loss.item()

            val_total += y_val.size(0)
            val_correct += ((torch.argmax(outputs, 1)==y_val)).sum().item()

        val_avg_loss = val_loss_sum / total_val_batch
        val_avg_accuracy = 100*val_correct / val_total

    return (val_avg_loss, val_avg_accuracy)

# %%
def model_test(dataloader, model):

    model.eval()

    with torch.no_grad():

        test_loss_sum = test_correct = test_total = 0

        total_test_batch = len(dataloader)

        for images, labels in dataloader:

            x_test = images.to(DEVICE)
            y_test = labels.to(DEVICE)

            outputs = model(x_test)
            loss = loss_function(outputs, y_test)

            test_loss_sum += loss.item()

            test_total += y_test.size(0)
            test_correct += ((torch.argmax(outputs, 1)==y_test)).sum().item()

        test_avg_loss = test_loss_sum / total_test_batch
        test_avg_accuracy = 100*test_correct / test_total

        print('accuracy:', test_avg_accuracy)
        print('loss:', test_avg_loss)

# %%
from datetime import datetime

train_loss_list = []
train_accuracy_list = []

val_loss_list = []
val_accuracy_list = []

start_time = datetime.now()

EPOCHS = 100

for epoch in range(EPOCHS):

    #==============  model train  ================
    train_avg_loss, train_avg_accuracy = model_train(train_dataset_loader, model, loss_function, optimizer)

    train_loss_list.append(train_avg_loss)
    train_accuracy_list.append(train_avg_accuracy)
    #=============================================

    #============  model evaluation  ==============
    val_avg_loss, val_avg_accuracy = model_evaluate(validation_dataset_loader, model, loss_function, optimizer)

    val_loss_list.append(val_avg_loss)
    val_accuracy_list.append(val_avg_accuracy)
    #============  model evaluation  ==============

    print('epoch:', '%02d' % (epoch + 1),
          'train loss =', '{:.3f}'.format(train_avg_loss), 'train acc =', '{:.3f}'.format(train_avg_accuracy),
          'val loss =', '{:.3f}'.format(val_avg_loss), 'val acc =', '{:.3f}'.format(val_avg_accuracy))

end_time = datetime.now()

print('elapsed time => ', end_time-start_time)
# Out:
# epoch: 01 train loss = 1.737 train acc = 36.026 val loss = 1.426 val acc = 48.947
# epoch: 02 train loss = 1.444 train acc = 47.631 val loss = 1.238 val acc = 56.013
# epoch: 03 train loss = 1.337 train acc = 51.699 val loss = 1.182 val acc = 58.347
# epoch: 04 train loss = 1.276 train acc = 54.108 val loss = 1.107 val acc = 61.547
# epoch: 05 train loss = 1.218 train acc = 56.334 val loss = 1.073 val acc = 63.187
# epoch: 06 train loss = 1.179 train acc = 57.819 val loss = 1.016 val acc = 64.173
# epoch: 07 train loss = 1.142 train acc = 59.520 val loss = 0.994 val acc = 64.827
# epoch: 08 train loss = 1.106 train acc = 60.706 val loss = 0.947 val acc = 67.067
# epoch: 09 train loss = 1.090 train acc = 61.056 val loss = 0.971 val acc = 65.187
# epoch: 10 train loss = 1.061 train acc = 62.447 val loss = 0.948 val acc = 66.520
# epoch: 11 train loss = 1.045 train acc = 62.988 val loss = 0.934 val acc = 67.907
# epoch: 12 train loss = 1.026 train acc = 63.751 val loss = 0.902 val acc = 68.427
# epoch: 13 train loss = 1.013 train acc = 63.929 val loss = 0.894 val acc = 68.920
# epoch: 14 train loss = 0.997 train acc = 64.638 val loss = 0.900 val acc = 69.133
# epoch: 15 train loss = 0.980 train acc = 65.101 val loss = 0.903 val acc = 67.933
# epoch: 16 train loss = 0.965 train acc = 65.656 val loss = 0.851 val acc = 70.400
# epoch: 17 train loss = 0.951 train acc = 66.153 val loss = 0.863 val acc = 70.093
# epoch: 18 train loss = 0.949 train acc = 66.134 val loss = 0.863 val acc = 69.720
# epoch: 19 train loss = 0.926 train acc = 67.165 val loss = 0.862 val acc = 70.080
# epoch: 20 train loss = 0.924 train acc = 67.096 val loss = 0.873 val acc = 69.533
# epoch: 21 train loss = 0.912 train acc = 67.659 val loss = 0.904 val acc = 68.280
# epoch: 22 train loss = 0.905 train acc = 67.824 val loss = 0.843 val acc = 70.667
# epoch: 23 train loss = 0.897 train acc = 68.261 val loss = 0.835 val acc = 71.040
# epoch: 24 train loss = 0.880 train acc = 68.605 val loss = 0.857 val acc = 70.360
# epoch: 25 train loss = 0.873 train acc = 68.861 val loss = 0.836 val acc = 70.853
# epoch: 26 train loss = 0.869 train acc = 68.951 val loss = 0.839 val acc = 71.320
# epoch: 27 train loss = 0.858 train acc = 69.447 val loss = 0.825 val acc = 71.427
# epoch: 28 train loss = 0.845 train acc = 69.711 val loss = 0.832 val acc = 71.160
# epoch: 29 train loss = 0.838 train acc = 69.927 val loss = 0.808 val acc = 71.773
# epoch: 30 train loss = 0.828 train acc = 70.409 val loss = 0.813 val acc = 71.760
# epoch: 31 train loss = 0.830 train acc = 70.261 val loss = 0.828 val acc = 70.987
# epoch: 32 train loss = 0.825 train acc = 70.447 val loss = 0.831 val acc = 71.280
# epoch: 33 train loss = 0.814 train acc = 70.908 val loss = 0.800 val acc = 72.227
# epoch: 34 train loss = 0.809 train acc = 71.007 val loss = 0.804 val acc = 72.347
# epoch: 35 train loss = 0.797 train acc = 71.511 val loss = 0.805 val acc = 72.507
# epoch: 36 train loss = 0.795 train acc = 71.473 val loss = 0.822 val acc = 72.227
# epoch: 37 train loss = 0.793 train acc = 71.522 val loss = 0.829 val acc = 71.747
# epoch: 38 train loss = 0.782 train acc = 71.988 val loss = 0.802 val acc = 72.840
# epoch: 39 train loss = 0.779 train acc = 72.122 val loss = 0.826 val acc = 72.120
# epoch: 40 train loss = 0.785 train acc = 71.856 val loss = 0.799 val acc = 72.747
# epoch: 41 train loss = 0.778 train acc = 71.946 val loss = 0.798 val acc = 73.080
# epoch: 42 train loss = 0.769 train acc = 72.304 val loss = 0.799 val acc = 72.573
# epoch: 43 train loss = 0.760 train acc = 72.621 val loss = 0.807 val acc = 72.627
# epoch: 44 train loss = 0.757 train acc = 72.748 val loss = 0.820 val acc = 72.627
# epoch: 45 train loss = 0.754 train acc = 72.833 val loss = 0.802 val acc = 72.520
# epoch: 46 train loss = 0.752 train acc = 73.111 val loss = 0.820 val acc = 72.533
# epoch: 47 train loss = 0.755 train acc = 72.840 val loss = 0.811 val acc = 72.427
# epoch: 48 train loss = 0.747 train acc = 73.256 val loss = 0.840 val acc = 71.467
# epoch: 49 train loss = 0.740 train acc = 73.334 val loss = 0.805 val acc = 72.747
# epoch: 50 train loss = 0.745 train acc = 73.141 val loss = 0.801 val acc = 72.853
# epoch: 51 train loss = 0.741 train acc = 73.256 val loss = 0.836 val acc = 71.760
# epoch: 52 train loss = 0.733 train acc = 73.494 val loss = 0.811 val acc = 72.000
# epoch: 53 train loss = 0.734 train acc = 73.294 val loss = 0.790 val acc = 73.147
# epoch: 54 train loss = 0.719 train acc = 73.795 val loss = 0.796 val acc = 73.347
# epoch: 55 train loss = 0.731 train acc = 73.506 val loss = 0.783 val acc = 73.000
# epoch: 56 train loss = 0.723 train acc = 73.927 val loss = 0.806 val acc = 72.693
# epoch: 57 train loss = 0.724 train acc = 73.393 val loss = 0.788 val acc = 73.853
# epoch: 58 train loss = 0.717 train acc = 73.967 val loss = 0.787 val acc = 72.973
# epoch: 59 train loss = 0.721 train acc = 74.089 val loss = 0.793 val acc = 73.027
# epoch: 60 train loss = 0.708 train acc = 74.129 val loss = 0.791 val acc = 73.533
# epoch: 61 train loss = 0.715 train acc = 74.209 val loss = 0.803 val acc = 73.120
# epoch: 62 train loss = 0.708 train acc = 74.332 val loss = 0.799 val acc = 73.080
# epoch: 63 train loss = 0.704 train acc = 74.466 val loss = 0.811 val acc = 72.707
# epoch: 64 train loss = 0.703 train acc = 74.358 val loss = 0.800 val acc = 72.587
# epoch: 65 train loss = 0.699 train acc = 74.402 val loss = 0.816 val acc = 73.307
# epoch: 66 train loss = 0.698 train acc = 74.779 val loss = 0.798 val acc = 73.387
# epoch: 67 train loss = 0.694 train acc = 74.609 val loss = 0.787 val acc = 73.747
# epoch: 68 train loss = 0.697 train acc = 74.732 val loss = 0.810 val acc = 72.880
# epoch: 69 train loss = 0.694 train acc = 74.675 val loss = 0.797 val acc = 72.947
# epoch: 70 train loss = 0.696 train acc = 74.696 val loss = 0.791 val acc = 73.213
# epoch: 71 train loss = 0.679 train acc = 75.551 val loss = 0.794 val acc = 72.987
# epoch: 72 train loss = 0.679 train acc = 75.219 val loss = 0.784 val acc = 73.453
# epoch: 73 train loss = 0.684 train acc = 75.104 val loss = 0.795 val acc = 73.080
# epoch: 74 train loss = 0.684 train acc = 75.249 val loss = 0.783 val acc = 73.333
# epoch: 75 train loss = 0.684 train acc = 75.226 val loss = 0.782 val acc = 73.267
# epoch: 76 train loss = 0.685 train acc = 74.849 val loss = 0.774 val acc = 73.267
# epoch: 77 train loss = 0.685 train acc = 75.120 val loss = 0.810 val acc = 73.213
# epoch: 78 train loss = 0.678 train acc = 75.442 val loss = 0.774 val acc = 73.467
# epoch: 79 train loss = 0.676 train acc = 75.346 val loss = 0.768 val acc = 73.400
# epoch: 80 train loss = 0.679 train acc = 75.482 val loss = 0.786 val acc = 72.947
# epoch: 81 train loss = 0.680 train acc = 75.426 val loss = 0.787 val acc = 72.880
# epoch: 82 train loss = 0.670 train acc = 75.824 val loss = 0.790 val acc = 73.360
# epoch: 83 train loss = 0.675 train acc = 75.513 val loss = 0.788 val acc = 73.333
# epoch: 84 train loss = 0.670 train acc = 75.708 val loss = 0.788 val acc = 73.453
# epoch: 85 train loss = 0.662 train acc = 76.038 val loss = 0.795 val acc = 73.720
# epoch: 86 train loss = 0.678 train acc = 75.440 val loss = 0.773 val acc = 74.187
# epoch: 87 train loss = 0.665 train acc = 75.748 val loss = 0.786 val acc = 73.693
# epoch: 88 train loss = 0.662 train acc = 75.868 val loss = 0.785 val acc = 73.200
# epoch: 89 train loss = 0.659 train acc = 75.720 val loss = 0.767 val acc = 74.173
# epoch: 90 train loss = 0.662 train acc = 76.009 val loss = 0.782 val acc = 73.280
# epoch: 91 train loss = 0.668 train acc = 75.621 val loss = 0.782 val acc = 73.440
# epoch: 92 train loss = 0.662 train acc = 75.932 val loss = 0.788 val acc = 73.347
# epoch: 93 train loss = 0.653 train acc = 76.252 val loss = 0.776 val acc = 74.027
# epoch: 94 train loss = 0.657 train acc = 76.078 val loss = 0.789 val acc = 73.747
# epoch: 95 train loss = 0.663 train acc = 76.061 val loss = 0.773 val acc = 73.773
# epoch: 96 train loss = 0.653 train acc = 76.362 val loss = 0.789 val acc = 73.587
# epoch: 97 train loss = 0.650 train acc = 76.212 val loss = 0.783 val acc = 73.507
# epoch: 98 train loss = 0.645 train acc = 76.668 val loss = 0.798 val acc = 72.653
# epoch: 99 train loss = 0.657 train acc = 76.061 val loss = 0.784 val acc = 73.213
# epoch: 100 train loss = 0.649 train acc = 76.435 val loss = 0.827 val acc = 72.653
# elapsed time =>  0:16:23.199588

# %%
# test dataset 으로 정확도 및 오차 테스트

model_test(test_dataset_loader, model)
# Out:
# accuracy: 72.83
# loss: 0.8235500223317723

# %%
import matplotlib.pyplot as plt

plt.title('Loss Trend')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(train_loss_list, label='train loss')
plt.plot(val_loss_list, label='validation loss')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('Accuracy Trend')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()

plt.plot(train_accuracy_list, label='train accuracy')
plt.plot(val_accuracy_list, label='validation accuracy')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Loss Trend')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.plot(train_loss_list, label='train')
plt.plot(val_loss_list, label='validation')
plt.legend()

plt.subplot(1,2,2)
plt.title('Accuracy Trend')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()
plt.plot(train_accuracy_list, label='train')
plt.plot(val_accuracy_list, label='validation')
plt.legend()

plt.show()
