# %%
import torch
from torch import nn
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

print(f"using PyTorch version: {torch.__version__}, Device: {DEVICE}")
# Out:
# using PyTorch version: 2.1.0+cu121, Device: cuda

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = datasets.CIFAR10(root='CIFAR10_data/', train=True, download=True,
                               transform=transform)

test_dataset = datasets.CIFAR10(root='CIFAR10_data/', train=False, download=True,
                              transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to CIFAR10_data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49153637.62it/s]
# Extracting CIFAR10_data/cifar-10-python.tar.gz to CIFAR10_data/
# Files already downloaded and verified

# %%
print(len(train_dataset))

train_dataset_size = int(len(train_dataset) * 0.85)
validation_dataset_size = int(len(train_dataset) * 0.15)

train_dataset, validation_dataset = random_split(train_dataset, [train_dataset_size, validation_dataset_size])

print(len(train_dataset), len(validation_dataset), len(test_dataset))
# Out:
# 50000
# 42500 7500 10000

# %%
BATCH_SIZE = 64
#BATCH_SIZE = 128

train_dataset_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset_loader = DataLoader(dataset=validation_dataset, batch_size=BATCH_SIZE, shuffle=True)

test_dataset_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
class MyCNNModel(nn.Module):

    def __init__(self):

        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)

        self.pooling = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(1 * 1 * 256, 128)
        self.fc2 = nn.Linear(128, 10)

        self.dropout25 = nn.Dropout(p=0.25)
        self.dropout50 = nn.Dropout(p=0.5)

    def forward(self, data):

        data = self.conv1(data)
        data = torch.relu(data)
        data = self.conv2(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv3(data)
        data = torch.relu(data)
        data = self.conv4(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv5(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv6(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv7(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = data.view(-1, 1 * 1 * 256)

        data = self.fc1(data)
        data = torch.relu(data)
        data = self.dropout50(data)

        logits = self.fc2(data)

        return logits

# %%
model = MyCNNModel().to(DEVICE)

loss_function = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)

# %%
def model_train(dataloader, model, loss_function, optimizer):

    model.train()

    train_loss_sum = train_correct = train_total = 0

    total_train_batch = len(dataloader)

    for images, labels in dataloader:

        x_train = images.to(DEVICE)
        y_train = labels.to(DEVICE)

        outputs = model(x_train)
        loss = loss_function(outputs, y_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss_sum += loss.item()

        train_total += y_train.size(0)
        train_correct += ((torch.argmax(outputs, 1)==y_train)).sum().item()

    train_avg_loss = train_loss_sum / total_train_batch
    train_avg_accuracy = 100*train_correct / train_total

    return (train_avg_loss, train_avg_accuracy)

# %%
def model_evaluate(dataloader, model, loss_function, optimizer):

    model.eval()

    with torch.no_grad():

        val_loss_sum = val_correct = val_total = 0

        total_val_batch = len(dataloader)

        for images, labels in dataloader:

            x_val = images.to(DEVICE)
            y_val = labels.to(DEVICE)

            outputs = model(x_val)
            loss = loss_function(outputs, y_val)

            val_loss_sum += loss.item()

            val_total += y_val.size(0)
            val_correct += ((torch.argmax(outputs, 1)==y_val)).sum().item()

        val_avg_loss = val_loss_sum / total_val_batch
        val_avg_accuracy = 100*val_correct / val_total

    return (val_avg_loss, val_avg_accuracy)

# %%
def model_test(dataloader, model):

    model.eval()

    with torch.no_grad():

        test_loss_sum = 0
        test_correct=0
        test_total = 0

        total_test_batch = len(dataloader)

        for images, labels in dataloader:

            x_test = images.to(DEVICE)
            y_test = labels.to(DEVICE)

            outputs = model(x_test)
            loss = loss_function(outputs, y_test)

            test_loss_sum += loss.item()

            test_total += y_test.size(0)
            test_correct += ((torch.argmax(outputs, 1)==y_test)).sum().item()

        test_avg_loss = test_loss_sum / total_test_batch
        test_avg_accuracy = 100*test_correct / test_total

        print('accuracy:', test_avg_accuracy)
        print('loss:', test_avg_loss)

# %%
from datetime import datetime

train_loss_list = []
train_accuracy_list = []

val_loss_list = []
val_accuracy_list = []

start_time = datetime.now()
EPOCHS = 200

for epoch in range(EPOCHS):

    #==============  model train  ================
    train_avg_loss, train_avg_accuracy = model_train(train_dataset_loader, model, loss_function, optimizer)

    train_loss_list.append(train_avg_loss)
    train_accuracy_list.append(train_avg_accuracy)
    #=============================================

    #============  model evaluation  ==============
    val_avg_loss, val_avg_accuracy = model_evaluate(validation_dataset_loader, model, loss_function, optimizer)

    val_loss_list.append(val_avg_loss)
    val_accuracy_list.append(val_avg_accuracy)
    #============  model evaluation  ==============

    print('epoch:', '%02d' % (epoch + 1),
          'train loss =', '{:.3f}'.format(train_avg_loss), 'train acc =', '{:.3f}'.format(train_avg_accuracy),
          'val loss =', '{:.3f}'.format(val_avg_loss), 'val acc =', '{:.3f}'.format(val_avg_accuracy))

end_time = datetime.now()

print('elapsed time => ', end_time-start_time)
# Out:
# epoch: 01 train loss = 1.852 train acc = 28.908 val loss = 1.469 val acc = 45.307
# epoch: 02 train loss = 1.426 train acc = 47.638 val loss = 1.295 val acc = 53.453
# epoch: 03 train loss = 1.210 train acc = 56.687 val loss = 0.999 val acc = 63.573
# epoch: 04 train loss = 1.074 train acc = 62.122 val loss = 0.916 val acc = 66.533
# epoch: 05 train loss = 0.990 train acc = 65.193 val loss = 0.841 val acc = 69.467
# epoch: 06 train loss = 0.935 train acc = 67.445 val loss = 0.778 val acc = 72.613
# epoch: 07 train loss = 0.883 train acc = 69.433 val loss = 0.786 val acc = 72.560
# epoch: 08 train loss = 0.846 train acc = 71.045 val loss = 0.740 val acc = 73.947
# epoch: 09 train loss = 0.819 train acc = 71.892 val loss = 0.718 val acc = 75.333
# epoch: 10 train loss = 0.794 train acc = 72.840 val loss = 0.703 val acc = 75.747
# epoch: 11 train loss = 0.765 train acc = 73.666 val loss = 0.727 val acc = 75.307
# epoch: 12 train loss = 0.775 train acc = 73.673 val loss = 0.651 val acc = 77.613
# epoch: 13 train loss = 0.733 train acc = 75.214 val loss = 0.651 val acc = 77.493
# epoch: 14 train loss = 0.714 train acc = 75.788 val loss = 0.636 val acc = 77.973
# epoch: 15 train loss = 0.709 train acc = 75.908 val loss = 0.648 val acc = 77.627
# epoch: 16 train loss = 0.693 train acc = 76.612 val loss = 0.642 val acc = 78.520
# epoch: 17 train loss = 0.672 train acc = 77.174 val loss = 0.667 val acc = 77.067
# epoch: 18 train loss = 0.670 train acc = 77.167 val loss = 0.626 val acc = 78.667
# epoch: 19 train loss = 0.659 train acc = 77.327 val loss = 0.616 val acc = 78.933
# epoch: 20 train loss = 0.650 train acc = 78.000 val loss = 0.637 val acc = 78.373
# epoch: 21 train loss = 0.643 train acc = 78.268 val loss = 0.610 val acc = 79.520
# epoch: 22 train loss = 0.632 train acc = 78.569 val loss = 0.597 val acc = 79.773
# epoch: 23 train loss = 0.628 train acc = 78.826 val loss = 0.601 val acc = 79.040
# epoch: 24 train loss = 0.625 train acc = 79.007 val loss = 0.594 val acc = 79.893
# epoch: 25 train loss = 0.624 train acc = 78.819 val loss = 0.596 val acc = 79.440
# epoch: 26 train loss = 0.605 train acc = 79.334 val loss = 0.627 val acc = 79.507
# epoch: 27 train loss = 0.616 train acc = 79.209 val loss = 0.595 val acc = 80.293
# epoch: 28 train loss = 0.593 train acc = 79.852 val loss = 0.561 val acc = 80.800
# epoch: 29 train loss = 0.588 train acc = 80.052 val loss = 0.599 val acc = 80.147
# epoch: 30 train loss = 0.602 train acc = 79.791 val loss = 0.572 val acc = 81.187
# epoch: 31 train loss = 0.595 train acc = 79.619 val loss = 0.578 val acc = 81.000
# epoch: 32 train loss = 0.588 train acc = 80.191 val loss = 0.589 val acc = 80.200
# epoch: 33 train loss = 0.586 train acc = 80.344 val loss = 0.563 val acc = 81.107
# epoch: 34 train loss = 0.581 train acc = 80.666 val loss = 0.550 val acc = 81.587
# epoch: 35 train loss = 0.581 train acc = 80.402 val loss = 0.562 val acc = 81.693
# epoch: 36 train loss = 0.574 train acc = 80.758 val loss = 0.581 val acc = 80.720
# epoch: 37 train loss = 0.570 train acc = 80.598 val loss = 0.565 val acc = 81.373
# epoch: 38 train loss = 0.578 train acc = 80.718 val loss = 0.565 val acc = 81.520
# epoch: 106 train loss = 0.500 train acc = 83.845 val loss = 0.570 val acc = 81.667
# epoch: 107 train loss = 0.508 train acc = 83.480 val loss = 0.568 val acc = 82.173
# epoch: 108 train loss = 0.504 train acc = 83.889 val loss = 0.539 val acc = 82.467
# epoch: 109 train loss = 0.507 train acc = 83.452 val loss = 0.544 val acc = 82.627
# epoch: 110 train loss = 0.504 train acc = 83.600 val loss = 0.593 val acc = 81.560
# epoch: 111 train loss = 0.498 train acc = 83.739 val loss = 0.562 val acc = 81.787
# epoch: 112 train loss = 0.505 train acc = 83.496 val loss = 0.553 val acc = 82.400
# epoch: 113 train loss = 0.505 train acc = 83.558 val loss = 0.544 val acc = 82.413
# epoch: 114 train loss = 0.496 train acc = 83.981 val loss = 0.571 val acc = 82.507
# epoch: 115 train loss = 0.518 train acc = 83.471 val loss = 0.563 val acc = 82.173
# epoch: 116 train loss = 0.513 train acc = 83.398 val loss = 0.567 val acc = 82.107
# epoch: 117 train loss = 0.509 train acc = 83.360 val loss = 0.575 val acc = 82.400
# epoch: 118 train loss = 0.507 train acc = 83.612 val loss = 0.593 val acc = 81.453
# epoch: 119 train loss = 0.509 train acc = 83.736 val loss = 0.576 val acc = 82.467
# epoch: 120 train loss = 0.512 train acc = 83.534 val loss = 0.580 val acc = 82.560
# epoch: 121 train loss = 0.503 train acc = 83.936 val loss = 0.596 val acc = 81.507
# epoch: 122 train loss = 0.510 train acc = 83.642 val loss = 0.563 val acc = 82.240
# epoch: 123 train loss = 0.513 train acc = 83.631 val loss = 0.576 val acc = 81.973
# epoch: 124 train loss = 0.496 train acc = 83.814 val loss = 0.557 val acc = 82.387
# epoch: 125 train loss = 0.505 train acc = 83.762 val loss = 0.550 val acc = 83.027
# epoch: 126 train loss = 0.501 train acc = 83.936 val loss = 0.623 val acc = 80.680
# epoch: 127 train loss = 0.504 train acc = 83.781 val loss = 0.602 val acc = 81.667
# epoch: 128 train loss = 0.507 train acc = 83.739 val loss = 0.566 val acc = 82.507
# epoch: 129 train loss = 0.511 train acc = 83.501 val loss = 0.558 val acc = 82.040
# epoch: 130 train loss = 0.510 train acc = 83.586 val loss = 0.580 val acc = 82.080
# epoch: 131 train loss = 0.513 train acc = 83.701 val loss = 0.570 val acc = 82.120
# epoch: 132 train loss = 0.518 train acc = 83.374 val loss = 0.582 val acc = 82.320
# epoch: 133 train loss = 0.507 train acc = 83.887 val loss = 0.571 val acc = 82.627
# epoch: 134 train loss = 0.531 train acc = 83.007 val loss = 0.558 val acc = 82.533
# epoch: 135 train loss = 0.505 train acc = 83.873 val loss = 0.562 val acc = 82.387
# epoch: 136 train loss = 0.511 train acc = 83.605 val loss = 0.567 val acc = 82.733
# epoch: 137 train loss = 0.509 train acc = 83.769 val loss = 0.559 val acc = 82.693
# epoch: 138 train loss = 0.516 train acc = 83.511 val loss = 0.557 val acc = 82.760
# epoch: 173 train loss = 0.508 train acc = 83.927 val loss = 0.585 val acc = 82.053
# epoch: 174 train loss = 0.508 train acc = 83.946 val loss = 0.616 val acc = 82.333
# epoch: 175 train loss = 0.509 train acc = 84.073 val loss = 0.563 val acc = 82.667
# epoch: 176 train loss = 0.507 train acc = 84.278 val loss = 0.589 val acc = 82.267
# epoch: 177 train loss = 0.542 train acc = 83.026 val loss = 0.560 val acc = 83.160
# epoch: 178 train loss = 0.498 train acc = 84.296 val loss = 0.575 val acc = 82.560
# epoch: 179 train loss = 0.516 train acc = 84.007 val loss = 0.575 val acc = 82.133
# epoch: 180 train loss = 0.506 train acc = 84.066 val loss = 0.584 val acc = 81.387
# epoch: 181 train loss = 0.505 train acc = 84.226 val loss = 0.577 val acc = 81.973
# epoch: 182 train loss = 0.513 train acc = 83.864 val loss = 0.603 val acc = 81.960
# epoch: 183 train loss = 0.502 train acc = 84.504 val loss = 0.563 val acc = 83.347
# epoch: 184 train loss = 0.514 train acc = 83.918 val loss = 0.556 val acc = 82.480
# epoch: 185 train loss = 0.508 train acc = 83.882 val loss = 0.566 val acc = 82.347
# epoch: 186 train loss = 0.492 train acc = 84.511 val loss = 0.560 val acc = 83.227
# epoch: 187 train loss = 0.520 train acc = 83.918 val loss = 0.563 val acc = 83.333
# epoch: 188 train loss = 0.512 train acc = 83.821 val loss = 0.566 val acc = 81.907
# epoch: 189 train loss = 0.509 train acc = 84.219 val loss = 0.596 val acc = 81.987
# epoch: 190 train loss = 0.503 train acc = 84.198 val loss = 0.580 val acc = 82.880
# epoch: 191 train loss = 0.508 train acc = 83.795 val loss = 0.546 val acc = 82.627
# epoch: 192 train loss = 0.517 train acc = 84.031 val loss = 0.563 val acc = 82.680
# epoch: 193 train loss = 0.508 train acc = 84.111 val loss = 0.561 val acc = 82.680
# epoch: 194 train loss = 0.492 train acc = 84.624 val loss = 0.558 val acc = 82.880
# epoch: 195 train loss = 0.515 train acc = 83.821 val loss = 0.559 val acc = 83.360
# epoch: 196 train loss = 0.513 train acc = 84.005 val loss = 0.582 val acc = 81.747
# epoch: 197 train loss = 0.508 train acc = 84.256 val loss = 0.570 val acc = 82.133
# epoch: 198 train loss = 0.497 train acc = 84.214 val loss = 0.597 val acc = 82.307
# epoch: 199 train loss = 0.518 train acc = 84.045 val loss = 0.580 val acc = 82.373
# epoch: 200 train loss = 0.526 train acc = 83.468 val loss = 0.568 val acc = 82.987
# elapsed time =>  1:02:38.148908

# %%
# test dataset 으로 정확도 및 오차 테스트

model_test(test_dataset_loader, model)
# Out:
# accuracy: 82.64
# loss: 0.5887626876496965

# %%
import matplotlib.pyplot as plt

plt.title('Loss Trend')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(train_loss_list, label='train loss')
plt.plot(val_loss_list, label='validation loss')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('Accuracy Trend')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()

plt.plot(train_accuracy_list, label='train accuracy')
plt.plot(val_accuracy_list, label='validation accuracy')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Loss Trend')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.plot(train_loss_list, label='train')
plt.plot(val_loss_list, label='validation')
plt.legend()

plt.subplot(1,2,2)
plt.title('Accuracy Trend')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()
plt.plot(train_accuracy_list, label='train')
plt.plot(val_accuracy_list, label='validation')
plt.legend()

plt.show()
