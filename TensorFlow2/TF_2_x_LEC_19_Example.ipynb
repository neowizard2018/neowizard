# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense
from tensorflow.keras import Sequential

# %% [markdown]
# y = sin(2x) + cos(x)

# %%
# data 생성

x = np.arange(0, 100, 0.1)
y = np.sin(2*x) + np.cos(x)

seq_data = y.reshape(-1,1)

print(seq_data.shape)
print(seq_data[:5])
# Out:
# (1000, 1)
# [[1.        ]
#  [1.1936735 ]
#  [1.36948492]
#  [1.51997896]
#  [1.63841708]]

# %%
plt.grid()
plt.title('sin(2x)+cos(x)')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.plot(seq_data)

plt.show()

# %%
def seq2dataset(seq, window, horizon):

    X = []
    Y = []

    for i in range(len(seq)-(window+horizon)+1):

        x = seq[i:(i+window)]
        y = (seq[i+window+horizon-1])

        X.append(x)
        Y.append(y)

    return np.array(X), np.array(Y)

# %%
w = 20  # window size
h = 1  # horizon factor

X, Y = seq2dataset(seq_data, w, h)

print(X.shape, Y.shape)
# Out:
# (980, 20, 1) (980, 1)

# %%
split_ratio = 0.8

split = int(split_ratio*len(X))

x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (784, 20, 1) (784, 1) (196, 20, 1) (196, 1)

# %%
model = Sequential()

#model.add(SimpleRNN(units=128, activation='tanh',input_shape=x_train[0].shape))

model.add(SimpleRNN(units=128, activation='tanh',input_shape=(20,1)))

model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 128)               16640
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
from datetime import datetime

start_time = datetime.now()

hist = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))

end_time = datetime.now()

print('Elapsed Time => ', end_time-start_time)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 4s 20ms/step - loss: 0.0548 - mae: 0.1539 - val_loss: 0.0039 - val_mae: 0.0515
# Epoch 2/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0014 - mae: 0.0284 - val_loss: 6.6290e-04 - val_mae: 0.0206
# Epoch 3/100
# 25/25 [==============================] - 0s 15ms/step - loss: 3.8304e-04 - mae: 0.0159 - val_loss: 1.3405e-04 - val_mae: 0.0098
# Epoch 4/100
# 25/25 [==============================] - 0s 15ms/step - loss: 8.3036e-05 - mae: 0.0073 - val_loss: 4.4532e-05 - val_mae: 0.0054
# Epoch 5/100
# 25/25 [==============================] - 0s 14ms/step - loss: 3.2207e-05 - mae: 0.0048 - val_loss: 2.6137e-05 - val_mae: 0.0042
# Epoch 6/100
# 25/25 [==============================] - 0s 14ms/step - loss: 2.4466e-05 - mae: 0.0040 - val_loss: 1.6571e-05 - val_mae: 0.0033
# Epoch 7/100
# 25/25 [==============================] - 0s 13ms/step - loss: 1.7243e-05 - mae: 0.0034 - val_loss: 1.5277e-05 - val_mae: 0.0032
# Epoch 8/100
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4425e-05 - mae: 0.0030 - val_loss: 8.1464e-06 - val_mae: 0.0023
# Epoch 9/100
# 25/25 [==============================] - 0s 14ms/step - loss: 1.0406e-05 - mae: 0.0026 - val_loss: 1.2658e-05 - val_mae: 0.0029
# Epoch 10/100
# 25/25 [==============================] - 0s 14ms/step - loss: 1.1346e-05 - mae: 0.0028 - val_loss: 1.0603e-05 - val_mae: 0.0026
# Epoch 11/100
# 25/25 [==============================] - 0s 14ms/step - loss: 8.9284e-06 - mae: 0.0025 - val_loss: 1.3062e-05 - val_mae: 0.0030
# Epoch 12/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.0859e-06 - mae: 0.0022 - val_loss: 7.1018e-06 - val_mae: 0.0022
# Epoch 13/100
# 25/25 [==============================] - 0s 14ms/step - loss: 6.1656e-06 - mae: 0.0020 - val_loss: 4.7280e-06 - val_mae: 0.0017
# Epoch 14/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.3574e-06 - mae: 0.0022 - val_loss: 1.3678e-05 - val_mae: 0.0031
# Epoch 15/100
# 25/25 [==============================] - 0s 14ms/step - loss: 8.6977e-06 - mae: 0.0024 - val_loss: 8.5271e-06 - val_mae: 0.0024
# Epoch 16/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.
100
# 25/25 [==============================] - 0s 15ms/step - loss: 2.7841e-05 - mae: 0.0041 - val_loss: 4.4908e-05 - val_mae: 0.0058
# Epoch 99/100
# 25/25 [==============================] - 0s 16ms/step - loss: 2.9513e-05 - mae: 0.0045 - val_loss: 1.5595e-05 - val_mae: 0.0036
# Epoch 100/100
# 25/25 [==============================] - 0s 15ms/step - loss: 2.5662e-05 - mae: 0.0039 - val_loss: 6.4495e-05 - val_mae: 0.0064
# Elapsed Time =>  0:00:41.755423

# %%
plt.title('Loss Trend')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend(loc='best')

plt.show()

# %%
pred = model.predict(x_test)

print(pred.shape)
# Out:
# (196, 1)

# %%
rand_idx = np.random.randint(0, len(y_test), size=5)

print('random idx = ',rand_idx, '\n')

print('pred  = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])

#print(pred[rand_idx])
#print(y_test[rand_idx])
# Out:
# random idx =  [114  81 137 189 124]
#
# pred  =  [ 0.21866089  1.7312331   0.69993514 -0.29282752 -0.11809225]
# label =  [ 0.21445792  1.7376515   0.69782559 -0.29520266 -0.12085209]

# %%
plt.plot(pred, label='prediction')
plt.plot(y_test, label='label')
plt.grid()
plt.legend(loc='best')

plt.show()

# %% [markdown]
# y = 0.5*sin(2x) - cos(x/2)

# %%
# data 생성

x = np.arange(0, 100, 0.1)
y = 0.5*np.sin(2*x) - np.cos(x/2.0)

seq_data = y.reshape(-1,1)

print(seq_data.shape)
print(seq_data[:5])
# Out:
# (1000, 1)
# [[-1.        ]
#  [-0.89941559]
#  [-0.80029499]
#  [-0.70644984]
#  [-0.62138853]]

# %%
plt.grid()
plt.title('0.5*sin(2x)-cos(x/2)')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.plot(seq_data)

plt.show()

# %%
w = 20  # window size
h = 1  # horizon factor

X, Y = seq2dataset(seq_data, w, h)

print(X.shape, Y.shape)
# Out:
# (980, 20, 1) (980, 1)

# %%
split_ratio = 0.8

split = int(split_ratio*len(X))

x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (784, 20, 1) (784, 1) (196, 20, 1) (196, 1)

# %%
model = Sequential()

model.add(SimpleRNN(units=128, activation='tanh', input_shape=x_train[0].shape))

model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 128)               16640
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
from datetime import datetime

start_time = datetime.now()

hist = model.fit(x_train, y_train, 
                 epochs=100, 
                 validation_data=(x_test, y_test))

end_time = datetime.now()

print('Elapsed Time => ', end_time-start_time)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0713 - mae: 0.1815 - val_loss: 0.0045 - val_mae: 0.0574
# Epoch 2/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0032 - mae: 0.0471 - val_loss: 0.0025 - val_mae: 0.0370
# Epoch 3/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0013 - mae: 0.0284 - val_loss: 9.9288e-04 - val_mae: 0.0230
# Epoch 4/100
# 25/25 [==============================] - 0s 15ms/step - loss: 6.5148e-04 - mae: 0.0200 - val_loss: 4.1135e-04 - val_mae: 0.0149
# Epoch 5/100
# 25/25 [==============================] - 0s 15ms/step - loss: 3.9934e-04 - mae: 0.0154 - val_loss: 3.6498e-04 - val_mae: 0.0156
# Epoch 6/100
# 25/25 [==============================] - 0s 15ms/step - loss: 3.7522e-04 - mae: 0.0149 - val_loss: 1.7431e-04 - val_mae: 0.0091
# Epoch 7/100
# 25/25 [==============================] - 0s 14ms/step - loss: 1.6333e-04 - mae: 0.0094 - val_loss: 1.5719e-04 - val_mae: 0.0098
# Epoch 8/100
# 25/25 [==============================] - 0s 14ms/step - loss: 1.
100
# 25/25 [==============================] - 0s 14ms/step - loss: 3.0099e-06 - mae: 0.0013 - val_loss: 6.0510e-06 - val_mae: 0.0021
# Epoch 87/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.9339e-06 - mae: 0.0023 - val_loss: 4.0143e-05 - val_mae: 0.0056
# Epoch 88/100
# 25/25 [==============================] - 0s 15ms/step - loss: 2.1148e-05 - mae: 0.0036 - val_loss: 1.5956e-05 - val_mae: 0.0034
# Epoch 89/100
# 25/25 [==============================] - 0s 15ms/step - loss: 2.4282e-05 - mae: 0.0041 - val_loss: 4.2206e-05 - val_mae: 0.0055
# Epoch 90/100
# 25/25 [==============================] - 0s 14ms/step - loss: 3.9861e-05 - mae: 0.0051 - val_loss: 2.6355e-05 - val_mae: 0.0041
# Epoch 91/100
# 25/25 [==============================] - 0s 15ms/step - loss: 9.4360e-06 - mae: 0.0024 - val_loss: 1.2212e-05 - val_mae: 0.0030
# Epoch 92/100
# 25/25 [==============================] - 0s 14ms/step - loss: 6.1086e-06 - mae: 0.0019 - val_loss: 7.9855e-06 - val_mae: 0.0023
# Epoch 93/100
# 25/25 [==============================] - 0s 15ms/step - loss: 2.2662e-05 - mae: 0.0037 - val_loss: 6.2908e-06 - val_mae: 0.0021
# Epoch 94/100
# 25/25 [==============================] - 0s 14ms/step - loss: 1.2200e-05 - mae: 0.0029 - val_loss: 1.6720e-05 - val_mae: 0.0032
# Epoch 95/100
# 25/25 [==============================] - 0s 14ms/step - loss: 1.0412e-05 - mae: 0.0026 - val_loss: 4.7513e-06 - val_mae: 0.0018
# Epoch 96/100
# 25/25 [==============================] - 0s 15ms/step - loss: 5.6492e-05 - mae: 0.0057 - val_loss: 8.2431e-05 - val_mae: 0.0078
# Epoch 97/100
# 25/25 [==============================] - 0s 15ms/step - loss: 9.8705e-05 - mae: 0.0081 - val_loss: 7.5196e-05 - val_mae: 0.0076
# Epoch 98/100
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8641e-05 - mae: 0.0056 - val_loss: 9.9065e-05 - val_mae: 0.0088
# Epoch 99/100
# 25/25 [==============================] - 0s 15ms/step - loss: 8.2472e-05 - mae: 0.0073 - val_loss: 5.8803e-05 - val_mae: 0.0064
# Epoch 100/100
# 25/25 [==============================] - 0s 15ms/step - loss: 9.6947e-05 - mae: 0.0079 - val_loss: 2.0068e-04 - val_mae: 0.0121
# Elapsed Time =>  0:00:41.564502

# %%
plt.title('Loss Trend')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend(loc='best')

plt.show()

# %%
pred = model.predict(x_test)

print(pred.shape)
# Out:
# (196, 1)

# %%
rand_idx = np.random.randint(0, len(y_test), size=5)

print('random idx = ',rand_idx, '\n')

print('pred  = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])

rand_idx = np.random.randint(0, len(y_test), size=5)

print('\n\nrandom idx = ',rand_idx, '\n')

print('pred  = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])
# Out:
# random idx =  [134  17  17  22 181]
#
# pred  =  [ 0.5648238   1.3228788   1.3228788   1.3594571  -0.13092087]
# label =  [ 0.58476182  1.34955716  1.34955716  1.37872936 -0.12930711]
#
#
# random idx =  [135 138 132 115   3]
#
# pred  =  [0.6439476  0.92936814 0.44922176 0.88762265 0.41067532]
# label =  [0.6645118  0.95200773 0.46682425 0.88649639 0.41993181]

# %%
plt.plot(pred, label='prediction')
plt.plot(y_test, label='label')
plt.grid()
plt.legend(loc='best')

plt.show()
